# %% [markdown]
# <a href="https://colab.research.google.com/github/marcos-bah/imersao-dados/blob/main/alura_imersao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01

# %%
import pandas as pd

source = "https://raw.githubusercontent.com/alura-cursos/imersao-dados-2-2020/master/MICRODADOS_ENEM_2019_SAMPLE_43278.csv"

data = pd.read_csv(source)
data.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q023  Q024 Q025
# 0  190001004661    2019                  1506138  ...    A     B    B
# 1  190001004674    2019                  1504208  ...    A     A    B
# 2  190001004722    2019                  1501402  ...    A     A    B
# 3  190001004735    2019                  1507300  ...    A     A    B
# 4  190001004776    2019                  1500800  ...    A     A    B
#
# [5 rows x 136 columns]

# %%
data.shape
# Out:
# (127380, 136)

# %%
data["SG_UF_RESIDENCIA"]
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
data.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
data[["SG_UF_RESIDENCIA", "Q025"]]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
data["SG_UF_RESIDENCIA"]
# Out:
# 0         PA
# 1         PA
# 2         PA
# 3         PA
# 4         PA
#           ..
# 127375    MG
# 127376    BA
# 127377    BA
# 127378    BA
# 127379    MG
# Name: SG_UF_RESIDENCIA, Length: 127380, dtype: object

# %%
data["SG_UF_RESIDENCIA"].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
len(data["SG_UF_RESIDENCIA"].unique())
# Out:
# 27

# %%
data["SG_UF_RESIDENCIA"].value_counts()
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
data["NU_IDADE"].value_counts()
# Out:
# 18    21452
# 17    21256
# 19    14418
# 20    10413
# 16     7830
#       ...
# 75        2
# 73        2
# 82        1
# 77        1
# 76        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
data["NU_IDADE"].value_counts().sort_index()
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
data["NU_IDADE"].hist()

# %%
data["NU_IDADE"].hist(bins = 20, figsize = (10,8))

# %% [markdown]
# **Desafio 01:** Proporção de inscritos por idade.
#
# **Desafio 02:** Descobrir de quais estados são os inscritos com 13 anos.
#
# **Desafio 03:** Colocar titulo no gráfico.
#
# **Desafio 4:** Plotar historiograma de treineiros e não treineiros por idade.
#
# **Desafio 5:** Comparar as distribuições das provas em inglês e espanhol.

# %%
data["NU_IDADE"].value_counts(normalize=True)
# Out:
# 18    0.168409
# 17    0.166871
# 19    0.113189
# 20    0.081748
# 16    0.061470
#         ...
# 75    0.000016
# 73    0.000016
# 82    0.000008
# 77    0.000008
# 76    0.000008
# Name: NU_IDADE, Length: 65, dtype: float64

# %%
data["SG_UF_RESIDENCIA"][data["NU_IDADE"]==13]
# Out:
# 57359     SP
# 95630     MT
# 98197     AP
# 116501    BA
# Name: SG_UF_RESIDENCIA, dtype: object

# %%
data["NU_IDADE"].hist(bins = 20, figsize = (10,8)).set_title("Frequencia por IDADE")
# Out:
# Text(0.5, 1.0, 'Frequencia por IDADE')

# %%
data.query("IN_TREINEIRO == 1")["NU_IDADE"].hist(bins = 30).set_title("Treineiros")
# Out:
# Text(0.5, 1.0, 'Treineiros')

# %%
data.query("IN_TREINEIRO != 1")["NU_IDADE"].hist(bins = 30).set_title("Não Treineiros")
# Out:
# Text(0.5, 1.0, 'Não Treineiros')

# %%
data.query("TP_LINGUA == 1")["NU_NOTA_LC"].hist(bins = 30).set_title("Inglês")
# Out:
# Text(0.5, 1.0, 'Inglês')

# %%
data.query("TP_LINGUA != 1")["NU_NOTA_LC"].hist(bins = 30).set_title("Espanhol")
# Out:
# Text(0.5, 1.0, 'Espanhol')

# %% [markdown]
# FIM DESAFIO

# %%
data.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
data["NU_NOTA_REDACAO"].hist(bins = 20, figsize=(8, 6))

# %%
data["NU_NOTA_LC"].hist(bins = 20, figsize=(8, 6))

# %%
data["NU_NOTA_REDACAO"].mean()
# Out:
# 571.5700253970197

# %%
data["NU_NOTA_REDACAO"].std()
# Out:
# 188.07645455749753

# %%
tests = ["NU_NOTA_CN", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_CH", "NU_NOTA_REDACAO"]

data[tests].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_MT    NU_NOTA_LC    NU_NOTA_CH  NU_NOTA_REDACAO
# count  92758.000000  92758.000000  98043.000000  98043.000000     98043.000000
# mean     477.964015    523.555206    520.463928    507.365912       571.570025
# std       76.296099    109.416939     64.556578     82.972839       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    435.300000    483.700000    447.900000       480.000000
# 50%      470.200000    501.600000    526.100000    510.900000       580.000000
# 75%      533.300000    598.200000    565.100000    567.100000       680.000000
# max      797.300000    985.000000    801.700000    809.400000      1000.000000

# %%
data["NU_NOTA_LC"].quantile(0.9)
# Out:
# 596.3

# %%
data[tests].plot.box(grid = True, figsize=(8,6))

# %% [markdown]
# Aula 02

# %% [markdown]
# **Desafio 0:** Quão comum uma pessoa de um estado faz a prova em outro estado.

# %%
data.query("SG_UF_ESC != SG_UF_RESIDENCIA")["SG_UF_ESC"].value_counts()
# Out:
# PE    26
# DF    21
# MG    13
# GO    11
# PI    10
# CE     8
# SP     7
# PR     6
# SC     6
# BA     5
# MA     5
# SE     4
# PA     4
# RJ     3
# RN     3
# ES     3
# AL     2
# MT     2
# AC     2
# PB     2
# AP     1
# RO     1
# Name: SG_UF_ESC, dtype: int64

# %%
data.query("SG_UF_ESC != SG_UF_RESIDENCIA")["SG_UF_ESC"].value_counts().plot.pie(figsize=(10,8))

# %%
data.query("SG_UF_ESC != SG_UF_RESIDENCIA")["SG_UF_ESC"].value_counts().plot.bar(figsize=(10,8))

# %% [markdown]
# **Mega Desafio da Thainá:** Pegar a amostra completa dos alunos de 13 e 14 anos.
#
# **Desafio do Gui Bonzinho:** a amostra para alunos menores de idade e comprar a aproporção de estados.
#
# **Deafio 3:** Criar função para PlotBox.
#
# **Desafio 4:** Verificar se quem zerou a prova foi eliminado ou não estava presente.
#
# **Desafio 5:** Quem é eliminado tira zero ou NaN?
#
# **Desafio 6:** Verificar proporção nas classes de renda como treineiro e não treineiro
#
# **Desafio 7:** Relação entre nota e acesso a internet.

# %%
data.query("NU_IDADE < 18")["SG_UF_RESIDENCIA"].value_counts(normalize=True)
# Out:
# SP    0.234347
# MG    0.100704
# BA    0.063796
# CE    0.062516
# PE    0.057778
# PR    0.056466
# RJ    0.052849
# PA    0.040589
# GO    0.038380
# MA    0.037260
# RS    0.031690
# PB    0.026825
# SC    0.025448
# PI    0.021703
# MT    0.019590
# ES    0.016549
# DF    0.015109
# AL    0.014277
# RN    0.013732
# AM    0.013700
# MS    0.013476
# SE    0.012964
# TO    0.011012
# RO    0.007490
# AP    0.006018
# AC    0.003489
# RR    0.002241
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
data.query("NU_IDADE < 18")["SG_UF_RESIDENCIA"].value_counts(normalize=True).plot.bar(figsize=(10,8))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
renda_ordenada = data["Q006"].unique()
renda_ordenada.sort()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y = "NU_NOTA_MT", data=data, order=renda_ordenada)
plt.title("BoxPlot de notas pela renda")
# Out:
# Text(0.5, 1.0, 'BoxPlot de notas pela renda')

# %%
data["NU_NOTA_TOTAL"] = data[tests].sum(axis=1)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="Q006", y = "NU_NOTA_TOTAL", data=data, order=renda_ordenada)
plt.title("BoxPlot de notas pela renda")
# Out:
# Text(0.5, 1.0, 'BoxPlot de notas pela renda')

# %%
sns.displot(data, x = "NU_NOTA_TOTAL")

# %%
tests += ['TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC', 'TP_PRESENCA_MT', 'NU_NOTA_TOTAL']

# %%
data[tests].query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_NOTA_CN  NU_NOTA_MT  ...  TP_PRESENCA_MT  NU_NOTA_TOTAL
# 10             NaN         NaN  ...               0            0.0
# 11             NaN         NaN  ...               0            0.0
# 26             NaN         NaN  ...               0            0.0
# 38             NaN         NaN  ...               0            0.0
# 40             NaN         NaN  ...               0            0.0
# ...            ...         ...  ...             ...            ...
# 127351         NaN         NaN  ...               0            0.0
# 127365         NaN         NaN  ...               0            0.0
# 127366         NaN         NaN  ...               0            0.0
# 127368         NaN         NaN  ...               0            0.0
# 127374         NaN         NaN  ...               0            0.0
#
# [29162 rows x 10 columns]

# %% [markdown]
# Desafio 3 - Função

# %%
def grafico(title, y, d, hue):
  plt.figure(figsize=(10,8))
  sns.boxplot(x="Q006", y = y, data=d, order=renda_ordenada, hue = hue,)
  plt.title(title)

# %% [markdown]
# Desafio 4 - Resolução

# %% [markdown]
# 0 - Ausente
# 1 - Presente
# 2 - Eliminado

# %%
data[tests].query("NU_NOTA_TOTAL == 0")["TP_PRESENCA_MT"].value_counts()
data[tests].query("NU_NOTA_TOTAL == 0")["TP_PRESENCA_LC"].value_counts()
data[tests].query("NU_NOTA_TOTAL == 0")["TP_PRESENCA_CN"].value_counts()
data[tests].query("NU_NOTA_TOTAL == 0")["TP_PRESENCA_CH"].value_counts()
# Out:
# 0    29001
# 2      120
# 1       41
# Name: TP_PRESENCA_CH, dtype: int64

# %% [markdown]
# Desafio 5 - Resolução

# %% [markdown]
# Participante recebe nota NaN

# %%
data[tests].query("TP_PRESENCA_MT == 2")["NU_NOTA_MT"]
# Out:
# 1784     NaN
# 2867     NaN
# 3411     NaN
# 5970     NaN
# 15619    NaN
# 16756    NaN
# 17035    NaN
# 24936    NaN
# 25454    NaN
# 27360    NaN
# 30042    NaN
# 36047    NaN
# 43694    NaN
# 44747    NaN
# 47088    NaN
# 49842    NaN
# 50943    NaN
# 55229    NaN
# 56242    NaN
# 58061    NaN
# 60225    NaN
# 61847    NaN
# 63315    NaN
# 63870    NaN
# 66579    NaN
# 68397    NaN
# 71474    NaN
# 71675    NaN
# 76027    NaN
# 77304    NaN
# 80839    NaN
# 81387    NaN
# 82582    NaN
# 84423    NaN
# 87083    NaN
# 87463    NaN
# 87789    NaN
# 91603    NaN
# 92473    NaN
# 93482    NaN
# 93997    NaN
# 95701    NaN
# 97725    NaN
# 98816    NaN
# 100003   NaN
# 110289   NaN
# 114896   NaN
# 117935   NaN
# 119045   NaN
# 120233   NaN
# 122716   NaN
# 125503   NaN
# Name: NU_NOTA_MT, dtype: float64

# %% [markdown]
# Desafio 6 - Resolução

# %%
data.query("IN_TREINEIRO == 1")["Q006"].value_counts(normalize=True).plot.bar(figsize=(10,8))

# %%
data.query("IN_TREINEIRO == 0")["Q006"].value_counts(normalize=True).plot.bar(figsize=(10,8))

# %% [markdown]
# Desafio 7 - Resolução

# %% [markdown]
# A - Não
# B - Sim

# %% [markdown]
# Reflexão:
# A nota tende a aumentar quando se tem acesso a internet, mas um caso curioso é a relação com a renda, sendo que as rendas maiores possuem discrepancia maior.
#
# No contexto da pandemia, se seguir essa relação, provavelmnete as notas de quem não possui acesso a internet se tornarão ainda mais baixas.

# %%
dados_sem_notas_zero = data.query("NU_NOTA_TOTAL != 0")
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025")

# %%
dados_sem_notas_zero.head()
grafico("BoxPlot das notas pelo acesso a internet", "NU_NOTA_TOTAL", dados_sem_notas_zero, "Q025")

# %% [markdown]
# **Fim Desafios 2 dia**

# %%
dados_sem_notas_zero = data.query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
grafico("BoxPlot das notas pela renda sem zeros", "NU_NOTA_TOTAL", dados_sem_notas_zero, "IN_TREINEIRO")

# %% [markdown]
# # Aula 3

# %%
plt.figure(figsize=(10, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL")

# %%
plt.figure(figsize=(10, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(10, 8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")

# %% [markdown]
# **Desafio 0:** Plota médias, medianas e moda nas notas de LC e MT.
#
# **Desafio 1:** Melhorar a visualização da matriz de correlação.
#
# **Desafio 2:** Gerar gráficos do estado.
#
# **Desafio 3:** Pensar sobre a correlação.

# %% [markdown]
# Desafio 0 - Resolução

# %%
plt.figure(figsize=(10, 8))
plt.axvline(dados_sem_notas_zero["NU_NOTA_MT"].mean(), color='red')
plt.axvline(dados_sem_notas_zero["NU_NOTA_MT"].median(), color='green')
plt.axvline(dados_sem_notas_zero["NU_NOTA_MT"].mode()[0], color='yellow')
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_MT")

# %%
plt.figure(figsize=(10, 8))
plt.axvline(dados_sem_notas_zero["NU_NOTA_LC"].mean(), color='red')
plt.axvline(dados_sem_notas_zero["NU_NOTA_LC"].median(), color='green')
plt.axvline(dados_sem_notas_zero["NU_NOTA_LC"].mode()[0], color='yellow')
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_LC")

# %% [markdown]
# Desafio 1 - Resolução

# %%
correlacao = dados_sem_notas_zero[tests[:5]].corr()
correlacao
# Out:
#                  NU_NOTA_CN  NU_NOTA_MT  ...  NU_NOTA_CH  NU_NOTA_REDACAO
# NU_NOTA_CN         1.000000    0.649527  ...    0.668979         0.504740
# NU_NOTA_MT         0.649527    1.000000  ...    0.610332         0.493046
# NU_NOTA_LC         0.641624    0.587710  ...    0.744170         0.535797
# NU_NOTA_CH         0.668979    0.610332  ...    1.000000         0.528338
# NU_NOTA_REDACAO    0.504740    0.493046  ...    0.528338         1.000000
#
# [5 rows x 5 columns]

# %%
import numpy as np
plt.subplots(figsize=(11, 9))
mask = np.triu(np.ones_like(correlacao, dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(correlacao, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.2, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 2 - Resolução

# %%
data.query("SG_UF_RESIDENCIA == 'MG' and NU_NOTA_TOTAL != 0")["NU_NOTA_TOTAL"].hist(bins = 30, figsize=(8, 6))

# %%
data.query("NU_NOTA_TOTAL != 0")["NU_NOTA_TOTAL"].hist(bins = 30, figsize=(8, 6))

# %% [markdown]
# Desafio 3 - Resolução
#
# Geralmente quem tira maior nota em CH tira melhor nota em Português e vice versa

# %% [markdown]
# Fim desafios

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True)

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="probability")

# %%
plt.figure(figsize=(12,8))
sns.histplot(dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue="Q025", kde=True, stat="density", cumulative=True)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data = dados_sem_notas_zero, x="NU_NOTA_MT", y="NU_NOTA_LC", hue="Q025")
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
tasks1 = ["NU_NOTA_CN", "NU_NOTA_MT", "NU_NOTA_LC", "NU_NOTA_CH", "NU_NOTA_REDACAO"]
sns.pairplot(dados_sem_notas_zero[tasks1])

# %%
sns.heatmap(correlacao, cmap="Blues", center=0, annot=True)

# %% [markdown]
# # Aula 4

# %%
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  ... Q024  Q025 NU_NOTA_TOTAL
# 0  190001004661    2019                  1506138  ...    B     B        2288.9
# 1  190001004674    2019                  1504208  ...    A     B        1184.6
# 2  190001004722    2019                  1501402  ...    A     B        2350.5
# 3  190001004735    2019                  1507300  ...    A     B        2555.7
# 4  190001004776    2019                  1500800  ...    A     B        2803.5
#
# [5 rows x 137 columns]

# %%
provas_entrada = ["NU_NOTA_CH", "NU_NOTA_CN", "NU_NOTA_LC", "NU_NOTA_REDACAO"]
prova_saida = "NU_NOTA_MT"
provas = ["NU_NOTA_CH", "NU_NOTA_CN", "NU_NOTA_LC", "NU_NOTA_REDACAO", "NU_NOTA_MT"]
dados_sem_notas_zero = dados_sem_notas_zero[provas].dropna()
notas_entrada = dados_sem_notas_zero[provas_entrada]
notas_saida = dados_sem_notas_zero[prova_saida]

# %%
notas_entrada
# Out:
#         NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_LC  NU_NOTA_REDACAO
# 0            512.3       435.6       488.6            420.0
# 2            499.1       423.2       441.0            560.0
# 3            578.1       426.2       551.5            500.0
# 4            571.3       516.5       511.2            780.0
# 5            618.7       559.6       607.5            900.0
# ...            ...         ...         ...              ...
# 127373       501.5       480.4       485.3            520.0
# 127375       559.6       502.4       525.7            740.0
# 127376       380.9       449.1       450.3            520.0
# 127378       416.2       564.7       517.3            620.0
# 127379       425.5       466.7       477.1            480.0
#
# [92537 rows x 4 columns]

# %%
x = notas_entrada
y = notas_saida

# %%
from sklearn.model_selection import train_test_split

SEED = 4321

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.25, random_state=SEED)

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state=SEED)
modelo.fit(x_treino, y_treino)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=4321, tol=0.0001, verbose=0)

# %%
predicoes_matematica = modelo.predict(x_teste)

# %%
y_teste[:5]
# Out:
# 114991    459.7
# 104685    617.2
# 91028     520.0
# 115802    703.8
# 93303     627.1
# Name: NU_NOTA_MT, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=predicoes_matematica, y=y_teste)
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=y_teste, y=y_teste - predicoes_matematica)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x=y_teste, y=x_teste.mean(axis=1))
plt.xlim((-50, 1050))
plt.ylim((-50, 1050))
# Out:
# (-50.0, 1050.0)

# %%
resultados = pd.DataFrame()
resultados["Real"] = y_teste
resultados["Previsao"] = predicoes_matematica
resultados["Diferenca"] = resultados["Real"] - resultados["Previsao"]
resultados["Diferenca^2"] = (resultados["Real"] - resultados["Previsao"])**2
resultados
# Out:
#          Real    Previsao   Diferenca   Diferenca^2
# 114991  459.7  564.486105 -104.786105  10980.127878
# 104685  617.2  628.305027  -11.105027    123.321625
# 91028   520.0  509.980986   10.019014    100.380650
# 115802  703.8  593.681144  110.118856  12126.162420
# 93303   627.1  579.784588   47.315412   2238.748252
# ...       ...         ...         ...           ...
# 81393   688.6  626.291851   62.308149   3882.305380
# 40159   479.1  652.313922 -173.213922  30003.062777
# 64083   501.4  607.787172 -106.387172  11318.230438
# 84661   772.5  734.227663   38.272337   1464.771772
# 79106   369.0  466.919690  -97.919690   9588.265665
#
# [23135 rows x 4 columns]

# %%
resultados["Diferenca^2"].mean()**(1/2)
# Out:
# 81.26755383435334

# %%
from sklearn.dummy import DummyRegressor

modelo_dummy = DummyRegressor()
modelo_dummy.fit(x_treino, y_treino)
dummy_predicoes = modelo_dummy.predict(x_teste)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_teste, dummy_predicoes)
# Out:
# 12063.645588509502

# %%
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# 6604.415306219554

# %% [markdown]
# **Desafio 0:** Procurar outro modelo e treinar e calcular outro erro.
#
# **Desafio 1:** Ler a documentação do dummy alterar metodo de regressão.
#
# **Desafio 2:** Buscar outra métrica para avaliar os modleos de regressão.

# %% [markdown]
# Fim Desafio

# %% [markdown]
# # Aula 5

# %%
from sklearn.svm import LinearSVR

modelo = LinearSVR(random_state = SEED)
modelo.fit(x_treino, y_treino)
predicoes_matematica = modelo.predict(x_teste)
mean_squared_error(y_teste, predicoes_matematica)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# 6604.415306219554

# %%
from sklearn.tree import DecisionTreeRegressor

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.25)
modelo_arvore = DecisionTreeRegressor(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
predicoes_matematica_arvore = modelo_arvore.predict(x_teste)
mean_squared_error(y_teste, predicoes_matematica_arvore)
# Out:
# 5971.573723737039

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import KFold
import numpy as np
SEED = 1232
np.random.seed(SEED)

partes = KFold(n_splits = 10, shuffle=True)
modelo_arvore = DecisionTreeRegressor(max_depth=3)
resultados = cross_validate(modelo_arvore, x, y, cv = partes, scoring="neg_mean_squared_error")

# %%
def calcula_mse(resultados):
  media = (resultados["test_score"]*-1).mean()
  desvio_padrao = (resultados["test_score"]*-1).std()

  lim_inferior = media - (2*desvio_padrao)
  lim_superior = media + (2*desvio_padrao)
  print(f"Limites {lim_inferior} - {lim_superior}")

# %%
def regressor_arvore(nivel):
  SEED = 1232
  np.random.seed(SEED)

  partes = KFold(n_splits = 10, shuffle=True)
  modelo_arvore = DecisionTreeRegressor(max_depth=nivel)
  resultados = cross_validate(modelo_arvore, x, y, cv = partes, scoring="neg_mean_squared_error", return_train_score=True)
  print(f"treino = {(resultados['train_score']*-1).mean()} - teste = {(resultados['test_score']*-1).mean()}")

regressor_arvore(10)
# Out:
# treino = 5022.598049115693 - teste = 5762.837933491856

# %%
calcula_mse(resultados)
# Out:
# Limites 5858.741842392759 - 6250.793292491382

# %%
for i in range(1,21):
  regressor_arvore(i)
# Out:
# treino = 7844.952652412207 - teste = 7857.8717702063495
# treino = 6527.783475408351 - teste = 6556.886287657658
# treino = 6021.275229419075 - teste = 6054.767567442071
# treino = 5760.834451245899 - teste = 5815.707286597402
# treino = 5598.158955426787 - teste = 5675.196789060743
# treino = 5469.677369145868 - teste = 5593.304363812442
# treino = 5369.458309852721 - teste = 5542.341606049669
# treino = 5276.16965707928 - teste = 5543.4943169272465
# treino = 5166.713159932668 - teste = 5610.015543751647
# treino = 5022.598049115693 - teste = 5762.837933491856
# treino = 4833.560706021637 - teste = 5957.2563212906625
# treino = 4598.125022484774 - teste = 6221.608447427583
# treino = 4316.3791662866815 - teste = 6522.136650215081
# treino = 4000.6209880837496 - teste = 6854.483925328223
# treino = 3655.8197526274853 - teste = 7227.189890233583
# treino = 3295.832684540846 - teste = 7638.44295804579
# treino = 2931.7212612043877 - teste = 8073.18661085159
# ...

# %% [markdown]
# **Desafio 01:** Pesquisar sobre intervalos de confiança.
# **Desafio 02:** Pesquisar outros parametros para melhorar a analise nas arvores de decisões.
#
# **Desafio 3:** Procurar outras formas de realisar os ajustes de parametro com o Sklearn.
#
# **Desafio 4:** Pesquisar o que é problema de underfit.
#
# **Deafio 5:** Criar gráficos com os dados para analisar o problema de underfit.
